# %% [markdown]
# # V1 IMAGE

# %% [markdown]
# ## FLEX

# %%
# def generate_order_flex(
#     items: list[dict],
#     transport_price: float,
#     order_id: str,
#     address: str = "-",
#     store_name: str = "Well daily",
#     store_address: str = "Marigold Lanna | Chiang Mai",
#     qr_url: str = "https://www.avasam.com/wp-content/uploads/2019/10/qr-sample.png",
#     button_url: str = "http://linecorp.com/",
#     button_label: str = "Transfer slip",
#     line_id_text: str = "welldailymeal",
# ) -> dict:
#     """
#     Generate LINE Flex Message (bubble) for order summary.

#     items example:
#     [
#         {"name": "Energy Drink", "quantity": 1, "price": 100},
#         {"name": "Chewing Gum", "quantity": 2, "price": 150},
#     ]
#     """

#     def money_fmt(value: float) -> str:
#         value = float(value)
#         return f"{int(value)}฿" if value.is_integer() else f"{value:.2f}฿"

#     total_items = 0
#     total_price = 0.0
#     item_contents = []

#     for item in items:
#         name = str(item["name"])
#         quantity = int(item["quantity"])
#         price = float(item["price"])

#         line_total = quantity * price
#         total_items += quantity
#         total_price += line_total

#         item_contents.append(
#             {
#                 "type": "box",
#                 "layout": "horizontal",
#                 "contents": [
#                     {
#                         "type": "text",
#                         "text": name,
#                         "size": "sm",
#                         "color": "#555555",
#                         "wrap": True,
#                         "flex": 3,
#                     },
#                     {
#                         "type": "text",
#                         "text": money_fmt(price),
#                         "size": "sm",
#                         "color": "#111111",
#                         "align": "end",
#                         "flex": 1,
#                     },
#                     {
#                         "type": "text",
#                         "text": f"x{quantity}",
#                         "size": "sm",
#                         "color": "#111111",
#                         "align": "end",
#                         "flex": 1,
#                     },
#                 ],
#                 "margin": "sm",
#             }
#         )

#     sum_total = total_price + float(transport_price)

#     return {
#         "type": "bubble",
#         "body": {
#             "type": "box",
#             "layout": "vertical",
#             "contents": [
#                 {
#                     "type": "text",
#                     "text": "Invoice",
#                     "weight": "bold",
#                     "color": "#1DB446",
#                     "size": "sm",
#                 },
#                 {
#                     "type": "text",
#                     "text": store_name,
#                     "weight": "bold",
#                     "size": "xxl",
#                     "margin": "md",
#                 },
#                 {
#                     "type": "text",
#                     "text": store_address,
#                     "size": "xs",
#                     "color": "#aaaaaa",
#                     "wrap": True,
#                 },
#                 {
#                     "type": "separator",
#                     "margin": "xl",
#                 },
#                 {
#                     "type": "box",
#                     "layout": "horizontal",
#                     "contents": [
#                         {
#                             "type": "text",
#                             "text": "menu",
#                             "flex": 3,
#                             "weight": "bold",
#                         },
#                         {
#                             "type": "text",
#                             "text": "price",
#                             "align": "end",
#                             "margin": "xxl",
#                             "flex": 1,
#                             "weight": "bold",
#                         },
#                         {
#                             "type": "text",
#                             "text": "qty",
#                             "align": "end",
#                             "flex": 1,
#                             "weight": "bold",
#                         },
#                     ],
#                 },
#                 {
#                     "type": "separator",
#                     "margin": "none",
#                 },
#                 {
#                     "type": "box",
#                     "layout": "vertical",
#                     "margin": "xxl",
#                     "spacing": "sm",
#                     "contents": item_contents + [
#                         {
#                             "type": "separator",
#                             "margin": "xxl",
#                         },
#                         {
#                             "type": "box",
#                             "layout": "horizontal",
#                             "margin": "xxl",
#                             "contents": [
#                                 {
#                                     "type": "text",
#                                     "text": "Items",
#                                     "size": "sm",
#                                     "color": "#555555",
#                                 },
#                                 {
#                                     "type": "text",
#                                     "text": str(total_items),
#                                     "size": "sm",
#                                     "color": "#111111",
#                                     "align": "end",
#                                 },
#                             ],
#                         },
#                         {
#                             "type": "box",
#                             "layout": "horizontal",
#                             "contents": [
#                                 {
#                                     "type": "text",
#                                     "text": "Total",
#                                     "size": "sm",
#                                     "color": "#555555",
#                                 },
#                                 {
#                                     "type": "text",
#                                     "text": money_fmt(total_price),
#                                     "size": "sm",
#                                     "color": "#111111",
#                                     "align": "end",
#                                 },
#                             ],
#                         },
#                         {
#                             "type": "box",
#                             "layout": "horizontal",
#                             "contents": [
#                                 {
#                                     "type": "text",
#                                     "text": "Transport",
#                                     "size": "sm",
#                                     "color": "#555555",
#                                 },
#                                 {
#                                     "type": "text",
#                                     "text": money_fmt(float(transport_price)),
#                                     "size": "sm",
#                                     "color": "#111111",
#                                     "align": "end",
#                                 },
#                             ],
#                         },
#                         {
#                             "type": "box",
#                             "layout": "horizontal",
#                             "contents": [
#                                 {
#                                     "type": "text",
#                                     "text": "Sum Total",
#                                     "size": "sm",
#                                     "color": "#555555",
#                                 },
#                                 {
#                                     "type": "text",
#                                     "text": money_fmt(sum_total),
#                                     "size": "sm",
#                                     "color": "#111111",
#                                     "align": "end",
#                                 },
#                             ],
#                         },
#                     ],
#                 },
#                 {
#                     "type": "separator",
#                     "margin": "xxl",
#                 },
#                 {
#                     "type": "box",
#                     "layout": "vertical",
#                     "contents": [
#                         {
#                             "type": "text",
#                             "text": "Address",
#                             "size": "sm",
#                             "weight": "bold",
#                         },
#                         {
#                             "type": "text",
#                             "text": address,
#                             "size": "xs",
#                             "margin": "xs",
#                             "wrap": True,
#                         },
#                     ],
#                 },
#                 {
#                     "type": "separator",
#                     "margin": "xxl",
#                 },
#                 {
#                     "type": "box",
#                     "layout": "horizontal",
#                     "margin": "md",
#                     "contents": [
#                         {
#                             "type": "text",
#                             "text": "ORDER ID",
#                             "size": "xs",
#                             "color": "#aaaaaa",
#                             "flex": 0,
#                         },
#                         {
#                             "type": "text",
#                             "text": order_id,
#                             "color": "#aaaaaa",
#                             "size": "xs",
#                             "align": "end",
#                             "wrap": False,
#                             "position": "relative",
#                         },
#                     ],
#                 },
#                 {
#                     "type": "image",
#                     "url": qr_url,
#                     "margin": "lg",
#                 },
#                 {
#                     "type": "text",
#                     "text": line_id_text,
#                     "align": "center",
#                 },
#                 {
#                     "type": "button",
#                     "action": {
#                         "type": "uri",
#                         "label": button_label,
#                         "uri": button_url,
#                     },
#                 },
#             ],
#         },
#         "styles": {
#             "footer": {
#                 "separator": True,
#             }
#         },
#     }

# %% [markdown]
# ## USED

# %%
items = [
    {"name": "Energy Drink more time free", "quantity": 1, "price": 100},
    {"name": "Chewing Gum", "quantity": 2, "price": 150},
    {"name": "MONO", "quantity": 1, "price": 150},
    {"name": "NEON", "quantity": 3, "price": 100},    
]

flex = generate_order_flex(
    items=items,
    transport_price=50,
    order_id="#DDxMMcYYpP01J6pHHmMNsSS",
    address="747 jubjub hanoi vietnam 78906",
)

flex
# Out:
# {'type': 'bubble',
#  'body': {'type': 'box',
#   'layout': 'vertical',
#   'contents': [{'type': 'text',
#     'text': 'Invoice',
#     'weight': 'bold',
#     'color': '#1DB446',
#     'size': 'sm'},
#    {'type': 'text',
#     'text': 'Well daily',
#     'weight': 'bold',
#     'size': 'xxl',
#     'margin': 'md'},
#    {'type': 'text',
#     'text': 'Marigold Lanna | Chiang Mai',
#     'size': 'xs',
#     'color': '#aaaaaa',
#     'wrap': True},
#    {'type': 'separator', 'margin': 'xl'},
#    {'type': 'box',
#     'layout': 'horizontal',
#     'contents': [{'type': 'text', 'text': 'menu', 'flex': 3, 'weight': 'bold'},
#      {'type': 'text',
#       'text': 'price',
#       'align': 'end',
#       'margin': 'xxl',
#       'flex': 1,
#       'weight': 'bold'},
#      {'type': 'text',
#       'text': 'qty',
#       'align': 'end',
#       'flex': 1,
#       'weight': 'bold'}]},
#    {'type': 'separator', 'margin': 'none'},
#    {'type': 'box',
#     'layout': 'vertical',
#     'margin': 'xxl',
#     'spacing': 'sm',
#     'contents': [{'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Energy Drink more time free',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '100฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x1',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Chewing Gum',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '150฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x2',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'MONO',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '150฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x1',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'NEON',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '100฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x3',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'separator', 'margin': 'xxl'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'margin': 'xxl',
#       'contents': [{'type': 'text',
#         'text': 'Items',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '7',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Total',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '850฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Transport',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '50฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Sum Total',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '900฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]}]},
#    {'type': 'separator', 'margin': 'xxl'},
#    {'type': 'box',
#     'layout': 'vertical',
#     'contents': [{'type': 'text',
#       'text': 'Address',
#       'size': 'sm',
#       'weight': 'bold'},
#      {'type': 'text',
#       'text': '747 jubjub hanoi vietnam 78906',
#       'size': 'xs',
#       'margin': 'xs',
#       'wrap': True}]},
#    {'type': 'separator', 'margin': 'xxl'},
#    {'type': 'box',
#     'layout': 'horizontal',
#     'margin': 'md',
#     'contents': [{'type': 'text',
#       'text': 'ORDER ID',
#       'size': 'xs',
#       'color': '#aaaaaa',
#       'flex': 0},
#      {'type': 'text',
#       'text': '#DDxMMcYYpP01J6pHHmMNsSS',
#       'color': '#aaaaaa',
#       'size': 'xs',
#       'align': 'end',
#       'wrap': False,
#       'position': 'relative'}]},
#    {'type': 'image',
#     'url': 'https://www.avasam.com/wp-content/uploads/2019/10/qr-sample.png',
#     'margin': 'lg'},
#    {'type': 'text', 'text': 'welldailymeal', 'align': 'center'},
#    {'type': 'button',
#     'action': {'type': 'uri',
#      'label': 'Transfer slip',
#      'uri': 'http://linecorp.com/'}}]},
#  'styles': {'footer': {'separator': True}}}

# %%
import json


json_payload = json.dumps(flex, ensure_ascii=False)
json_payload
# Out:
# '{"type": "bubble", "body": {"type": "box", "layout": "vertical", "contents": [{"type": "text", "text": "Invoice", "weight": "bold", "color": "#1DB446", "size": "sm"}, {"type": "text", "text": "Well daily", "weight": "bold", "size": "xxl", "margin": "md"}, {"type": "text", "text": "Marigold Lanna | Chiang Mai", "size": "xs", "color": "#aaaaaa", "wrap": true}, {"type": "separator", "margin": "xl"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "menu", "flex": 3, "weight": "bold"}, {"type": "text", "text": "price", "align": "end", "margin": "xxl", "flex": 1, "weight": "bold"}, {"type": "text", "text": "qty", "align": "end", "flex": 1, "weight": "bold"}]}, {"type": "separator", "margin": "none"}, {"type": "box", "layout": "vertical", "margin": "xxl", "spacing": "sm", "contents": [{"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Energy Drink more time free", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "100฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x1", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Chewing Gum", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "150฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x2", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "MONO", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "150฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x1", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "NEON", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "100฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x3", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "horizontal", "margin": "xxl", "contents": [{"type": "text", "text": "Items", "size": "sm", "color": "#555555"}, {"type": "text", "text": "7", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Total", "size": "sm", "color": "#555555"}, {"type": "text", "text": "850฿", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Transport", "size": "sm", "color": "#555555"}, {"type": "text", "text": "50฿", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Sum Total", "size": "sm", "color": "#555555"}, {"type": "text", "text": "900฿", "size": "sm", "color": "#111111", "align": "end"}]}]}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "vertical", "contents": [{"type": "text", "text": "Address", "size": "sm", "weight": "bold"}, {"type": "text", "text": "747 jubjub hanoi vietnam 78906", "size": "xs", "margin": "xs", "wrap": true}]}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "horizontal", "margin": "md", "contents": [{"type": "text", "text": "ORDER ID", "size": "xs", "color": "#aaaaaa", "flex": 0}, {"type": "text", "text": "#DDxMMcYYpP01J6pHHmMNsSS", "color": "#aaaaaa", "size": "xs", "align": "end", "wrap": false, "position": "relative"}]}, {"type": "image", "url": "https://www.avasam.com/wp-content/uploads/2019/10/qr-sample.png", "margin": "lg"}, {"type": "text", "text": "welldailymeal", "align": "center"}, {"type": "button", "action": {"type": "uri", "label": "Transfer slip", "u ...

# %%
import json


flex_res = json.loads(json_payload)
flex_res
# Out:
# {'type': 'bubble',
#  'body': {'type': 'box',
#   'layout': 'vertical',
#   'contents': [{'type': 'text',
#     'text': 'ORDER',
#     'weight': 'bold',
#     'color': '#1DB446',
#     'size': 'sm'},
#    {'type': 'text',
#     'text': 'Well daily',
#     'weight': 'bold',
#     'size': 'xxl',
#     'margin': 'md'},
#    {'type': 'text',
#     'text': 'Marigold Lanna | Chiang Mai',
#     'size': 'xs',
#     'color': '#aaaaaa',
#     'wrap': True},
#    {'type': 'separator', 'margin': 'xl'},
#    {'type': 'box',
#     'layout': 'horizontal',
#     'contents': [{'type': 'text', 'text': 'menu', 'flex': 3},
#      {'type': 'text',
#       'text': 'price',
#       'align': 'end',
#       'margin': 'xxl',
#       'flex': 1},
#      {'type': 'text', 'text': 'qty', 'align': 'end', 'flex': 1}]},
#    {'type': 'separator', 'margin': 'none'},
#    {'type': 'box',
#     'layout': 'vertical',
#     'margin': 'xxl',
#     'spacing': 'sm',
#     'contents': [{'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Energy Drink more time free',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '100฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x1',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Chewing Gum',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '150฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x2',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Chewing Gum 2',
#         'size': 'sm',
#         'color': '#555555',
#         'wrap': True,
#         'flex': 3},
#        {'type': 'text',
#         'text': '150฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1},
#        {'type': 'text',
#         'text': 'x1',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end',
#         'flex': 1}],
#       'margin': 'sm'},
#      {'type': 'separator', 'margin': 'xxl'},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'margin': 'xxl',
#       'contents': [{'type': 'text',
#         'text': 'ITEMS',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '4',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'TOTAL',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '550฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'Transport',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '50฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]},
#      {'type': 'box',
#       'layout': 'horizontal',
#       'contents': [{'type': 'text',
#         'text': 'SUM TOTAL',
#         'size': 'sm',
#         'color': '#555555'},
#        {'type': 'text',
#         'text': '600฿',
#         'size': 'sm',
#         'color': '#111111',
#         'align': 'end'}]}]},
#    {'type': 'separator', 'margin': 'xxl'},
#    {'type': 'box',
#     'layout': 'horizontal',
#     'margin': 'md',
#     'contents': [{'type': 'text',
#       'text': 'ORDER ID',
#       'size': 'xs',
#       'color': '#aaaaaa',
#       'flex': 0},
#      {'type': 'text',
#       'text': '#743289384279',
#       'color': '#aaaaaa',
#       'size': 'xs',
#       'align': 'end'}]},
#    {'type': 'image',
#     'url': 'https://www.avasam.com/wp-content/uploads/2019/10/qr-sample.png',
#     'margin': 'md'},
#    {'type': 'text', 'text': 'welldailymeal', 'align': 'center'},
#    {'type': 'button',
#     'action': {'type': 'uri',
#      'label': 'Transfer slip',
#      'uri': 'http://linecorp.com/'}}]},
#  'styles': {'footer': {'separator': True}}}

# %%
# pip install line-bot-sdk

# %%
# Out:
# linebot.models.flex_message.FlexContainer

# %% [markdown]
# # V2 (image)

# %%
def generate_order_flex(
    items: list[dict],
    total_items: int | str,
    total_price: float | str,
    transport_price: float | str,
    sum_total: float | str,
    order_id: str,
    address: str = "-",
    store_name: str = "Well daily",
    store_address: str = "Marigold Lanna | Chiang Mai",
    qr_url: str = "https://www.avasam.com/wp-content/uploads/2019/10/qr-sample.png",
    button_url: str = "http://linecorp.com/",
    button_label: str = "Transfer slip",
    line_id_text: str = "welldailymeal",
) -> dict:

    def money_fmt(value) -> str:
        if isinstance(value, str):
            return value if "฿" in value else f"{value}฿"

        value = float(value)
        return f"{int(value)}฿" if value.is_integer() else f"{value:.2f}฿"

    item_contents = []

    for item in items:
        name = str(item["name"])
        quantity = str(item["quantity"])
        price = item["price"]

        item_contents.append(
            {
                "type": "box",
                "layout": "horizontal",
                "contents": [
                    {
                        "type": "text",
                        "text": name,
                        "size": "sm",
                        "color": "#555555",
                        "wrap": True,
                        "flex": 3,
                    },
                    {
                        "type": "text",
                        "text": money_fmt(price),
                        "size": "sm",
                        "color": "#111111",
                        "align": "end",
                        "flex": 1,
                    },
                    {
                        "type": "text",
                        "text": f"x{quantity}",
                        "size": "sm",
                        "color": "#111111",
                        "align": "end",
                        "flex": 1,
                    },
                ],
                "margin": "sm",
            }
        )

    return {
        "type": "bubble",
        "body": {
            "type": "box",
            "layout": "vertical",
            "contents": [
                {
                    "type": "text",
                    "text": "Invoice",
                    "weight": "bold",
                    "color": "#1DB446",
                    "size": "sm",
                },
                {
                    "type": "text",
                    "text": store_name,
                    "weight": "bold",
                    "size": "xxl",
                    "margin": "md",
                },
                {
                    "type": "text",
                    "text": store_address,
                    "size": "xs",
                    "color": "#aaaaaa",
                    "wrap": True,
                },
                {"type": "separator", "margin": "xl"},
                {
                    "type": "box",
                    "layout": "horizontal",
                    "contents": [
                        {"type": "text", "text": "menu", "flex": 3, "weight": "bold"},
                        {
                            "type": "text",
                            "text": "price",
                            "align": "end",
                            "margin": "xxl",
                            "flex": 1,
                            "weight": "bold",
                        },
                        {
                            "type": "text",
                            "text": "qty",
                            "align": "end",
                            "flex": 1,
                            "weight": "bold",
                        },
                    ],
                },
                {"type": "separator", "margin": "none"},
                {
                    "type": "box",
                    "layout": "vertical",
                    "margin": "xxl",
                    "spacing": "sm",
                    "contents": item_contents
                    + [
                        {"type": "separator", "margin": "xxl"},
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "margin": "xxl",
                            "contents": [
                                {"type": "text", "text": "Items", "size": "sm", "color": "#555555"},
                                {
                                    "type": "text",
                                    "text": str(total_items),
                                    "size": "sm",
                                    "color": "#111111",
                                    "align": "end",
                                },
                            ],
                        },
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {"type": "text", "text": "Total", "size": "sm", "color": "#555555"},
                                {
                                    "type": "text",
                                    "text": money_fmt(total_price),
                                    "size": "sm",
                                    "color": "#111111",
                                    "align": "end",
                                },
                            ],
                        },
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {"type": "text", "text": "Transport", "size": "sm", "color": "#555555"},
                                {
                                    "type": "text",
                                    "text": money_fmt(transport_price),
                                    "size": "sm",
                                    "color": "#111111",
                                    "align": "end",
                                },
                            ],
                        },
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {"type": "text", "text": "Sum Total", "size": "sm", "color": "#555555"},
                                {
                                    "type": "text",
                                    "text": money_fmt(sum_total),
                                    "size": "sm",
                                    "color": "#111111",
                                    "align": "end",
                                },
                            ],
                        },
                    ],
                },
                {"type": "separator", "margin": "xxl"},
                {
                    "type": "box",
                    "layout": "vertical",
                    "contents": [
                        {"type": "text", "text": "Address", "size": "sm", "weight": "bold"},
                        {
                            "type": "text",
                            "text": address,
                            "size": "xs",
                            "margin": "xs",
                            "wrap": True,
                        },
                    ],
                },
                {"type": "separator", "margin": "xxl"},
                {
                    "type": "box",
                    "layout": "horizontal",
                    "margin": "md",
                    "contents": [
                        {
                            "type": "text",
                            "text": "ORDER ID",
                            "size": "xs",
                            "color": "#aaaaaa",
                            "flex": 0,
                        },
                        {
                            "type": "text",
                            "text": order_id,
                            "color": "#aaaaaa",
                            "size": "xs",
                            "align": "end",
                            "wrap": False,
                            "position": "relative",
                        },
                    ],
                },
                {"type": "image", "url": qr_url, "margin": "lg"},
                {"type": "text", "text": line_id_text, "align": "center"},
                {
                    "type": "button",
                    "action": {
                        "type": "uri",
                        "label": button_label,
                        "uri": button_url,
                    },
                },
            ],
        },
        "styles": {"footer": {"separator": True}},
    }

# %%
flex_json = generate_order_flex(
    items=[
        {"name": "Energy Drink more time free", "quantity": 1, "price": 100},
        {"name": "Chewing Gum", "quantity": 2, "price": 150},
    ],
    total_items=3,
    total_price=400,
    transport_price=50,
    sum_total=450,
    order_id="#743289384279",
    address="747 jubjub hanoi vietnam 78906",
    store_name="Well daily",
    store_address="Marigold Lanna | Chiang Mai",
    button_url= "http://linecorp.com/",
    button_label= "Transfer slip",
    line_id_text="welldailymeal"


)

# %%
import json
json_payload = json.dumps(flex_json, ensure_ascii=False)
json_payload
# Out:
# '{"type": "bubble", "body": {"type": "box", "layout": "vertical", "contents": [{"type": "text", "text": "Invoice", "weight": "bold", "color": "#1DB446", "size": "sm"}, {"type": "text", "text": "Well daily", "weight": "bold", "size": "xxl", "margin": "md"}, {"type": "text", "text": "Marigold Lanna | Chiang Mai", "size": "xs", "color": "#aaaaaa", "wrap": true}, {"type": "separator", "margin": "xl"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "menu", "flex": 3, "weight": "bold"}, {"type": "text", "text": "price", "align": "end", "margin": "xxl", "flex": 1, "weight": "bold"}, {"type": "text", "text": "qty", "align": "end", "flex": 1, "weight": "bold"}]}, {"type": "separator", "margin": "none"}, {"type": "box", "layout": "vertical", "margin": "xxl", "spacing": "sm", "contents": [{"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Energy Drink more time free", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "100฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x1", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Chewing Gum", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "150฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x2", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "horizontal", "margin": "xxl", "contents": [{"type": "text", "text": "Items", "size": "sm", "color": "#555555"}, {"type": "text", "text": "3", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Total", "size": "sm", "color": "#555555"}, {"type": "text", "text": "400฿", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Transport", "size": "sm", "color": "#555555"}, {"type": "text", "text": "50฿", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Sum Total", "size": "sm", "color": "#555555"}, {"type": "text", "text": "450฿", "size": "sm", "color": "#111111", "align": "end"}]}]}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "vertical", "contents": [{"type": "text", "text": "Address", "size": "sm", "weight": "bold"}, {"type": "text", "text": "747 jubjub hanoi vietnam 78906", "size": "xs", "margin": "xs", "wrap": true}]}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "horizontal", "margin": "md", "contents": [{"type": "text", "text": "ORDER ID", "size": "xs", "color": "#aaaaaa", "flex": 0}, {"type": "text", "text": "#743289384279", "color": "#aaaaaa", "size": "xs", "align": "end", "wrap": false, "position": "relative"}]}, {"type": "image", "url": "https://www.avasam.com/wp-content/uploads/2019/10/qr-sample.png", "margin": "lg"}, {"type": "text", "text": "welldailymeal", "align": "center"}, {"type": "button", "action": {"type": "uri", "label": "Transfer slip", "uri": "http://linecorp.com/"}}]}, "styles": {"footer": {"separator": true}}}'

# %% [markdown]
# # V3

# %% [markdown]
# ## FLEX

# %%
# %%writefile line_utils/generate_item_order_flex.py

def generate_order_flex(
    items: list[dict],
    total_items: int | str,
    total_price: float | str,
    transport_price: float | str,
    sum_total: float | str,
    order_id: str,
    address: str = "-",
    store_name: str = "Well daily",
    store_address: str = "Marigold Lanna | Chiang Mai",
    button_url: str = "http://linecorp.com/",
    button_label: str = "Transfer slip",
) -> dict:

    def money_fmt(value) -> str:
        if isinstance(value, str):
            return value if "฿" in value else f"{value}฿"
        value = float(value)
        return f"{int(value)}฿" if value.is_integer() else f"{value:.2f}฿"

    item_contents = []

    for item in items:
        item_contents.append({
            "type": "box",
            "layout": "horizontal",
            "contents": [
                {
                    "type": "text",
                    "text": str(item["name"]),
                    "size": "sm",
                    "color": "#555555",
                    "wrap": True,
                    "flex": 3,
                },
                {
                    "type": "text",
                    "text": money_fmt(item["price"]),
                    "size": "sm",
                    "color": "#111111",
                    "align": "end",
                    "flex": 1,
                },
                {
                    "type": "text",
                    "text": f'x{item["quantity"]}',
                    "size": "sm",
                    "color": "#111111",
                    "align": "end",
                    "flex": 1,
                },
            ],
            "margin": "sm",
        })

    return {
        "type": "bubble",
        "body": {
            "type": "box",
            "layout": "vertical",
            "contents": [
                {"type": "text", "text": "Invoice", "weight": "bold", "color": "#1DB446", "size": "sm"},
                {"type": "text", "text": store_name, "weight": "bold", "size": "xxl", "margin": "md"},
                {"type": "text", "text": store_address, "size": "xs", "color": "#aaaaaa", "wrap": True},
                {"type": "separator", "margin": "xl"},
                {
                    "type": "box",
                    "layout": "horizontal",
                    "contents": [
                        {"type": "text", "text": "menu", "flex": 3, "weight": "bold"},
                        {"type": "text", "text": "price", "align": "end", "margin": "xxl", "flex": 1, "weight": "bold"},
                        {"type": "text", "text": "qty", "align": "end", "flex": 1, "weight": "bold"},
                    ],
                },
                {"type": "separator", "margin": "none"},
                {
                    "type": "box",
                    "layout": "vertical",
                    "margin": "xxl",
                    "spacing": "sm",
                    "contents": item_contents + [
                        {"type": "separator", "margin": "xxl"},
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "margin": "xxl",
                            "contents": [
                                {"type": "text", "text": "Items", "size": "sm", "color": "#555555"},
                                {"type": "text", "text": str(total_items), "size": "sm", "color": "#111111", "align": "end"},
                            ],
                        },
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {"type": "text", "text": "Total", "size": "sm", "color": "#555555"},
                                {"type": "text", "text": money_fmt(total_price), "size": "sm", "color": "#111111", "align": "end"},
                            ],
                        },
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {"type": "text", "text": "Transport", "size": "sm", "color": "#555555"},
                                {"type": "text", "text": money_fmt(transport_price), "size": "sm", "color": "#111111", "align": "end"},
                            ],
                        },
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {"type": "text", "text": "Sum Total", "size": "sm", "color": "#555555"},
                                {"type": "text", "text": money_fmt(sum_total), "size": "sm", "color": "#111111", "align": "end"},
                            ],
                        },
                    ],
                },
                {"type": "separator", "margin": "xxl"},
                {
                    "type": "box",
                    "layout": "vertical",
                    "contents": [
                        {"type": "text", "text": "Address", "size": "sm", "weight": "bold"},
                        {"type": "text", "text": address, "size": "xs", "margin": "xs", "wrap": True},
                    ],
                },
                {"type": "separator", "margin": "xxl"},
                {
                    "type": "box",
                    "layout": "horizontal",
                    "margin": "md",
                    "contents": [
                        {"type": "text", "text": "ORDER ID", "size": "xs", "color": "#aaaaaa", "flex": 0},
                        {
                            "type": "text",
                            "text": order_id,
                            "color": "#aaaaaa",
                            "size": "xs",
                            "align": "end",
                            "wrap": False,
                            "position": "relative",
                        },
                    ],
                },
                {
                    "type": "button",
                    "action": {
                        "type": "uri",
                        "label": button_label,
                        "uri": button_url,
                    },
                },
            ],
        },
        "styles": {"footer": {"separator": True}},
    }
# Out:
# Overwriting line_utils/generate_item_order_flex.py

# %%
from line_utils.generate_item_order_flex import generate_order_flex
flex_json = generate_order_flex(
    items=[
        {"name": "Energy Drink more time free", "quantity": 1, "price": 100},
        {"name": "Chewing Gum", "quantity": 2, "price": 150},
    ],
    total_items=2,
    total_price=0,
    transport_price=0,
    sum_total=0,
    order_id="#743289384279",
    address="747 jubjub hanoi vietnam 78906",
    store_name="Well daily",
    store_address="Marigold Lanna | Chiang Mai",
    button_url= "http://linecorp.com/",
    button_label= "Transfer slip",
)

# %%
import json
json_payload = json.dumps(flex_json, ensure_ascii=False)
json_payload
# Out:
# '{"type": "bubble", "body": {"type": "box", "layout": "vertical", "contents": [{"type": "text", "text": "Invoice", "weight": "bold", "color": "#1DB446", "size": "sm"}, {"type": "text", "text": "Well daily", "weight": "bold", "size": "xxl", "margin": "md"}, {"type": "text", "text": "Marigold Lanna | Chiang Mai", "size": "xs", "color": "#aaaaaa", "wrap": true}, {"type": "separator", "margin": "xl"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "menu", "flex": 3, "weight": "bold"}, {"type": "text", "text": "price", "align": "end", "margin": "xxl", "flex": 1, "weight": "bold"}, {"type": "text", "text": "qty", "align": "end", "flex": 1, "weight": "bold"}]}, {"type": "separator", "margin": "none"}, {"type": "box", "layout": "vertical", "margin": "xxl", "spacing": "sm", "contents": [{"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Energy Drink more time free", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "100฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x1", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Chewing Gum", "size": "sm", "color": "#555555", "wrap": true, "flex": 3}, {"type": "text", "text": "150฿", "size": "sm", "color": "#111111", "align": "end", "flex": 1}, {"type": "text", "text": "x2", "size": "sm", "color": "#111111", "align": "end", "flex": 1}], "margin": "sm"}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "horizontal", "margin": "xxl", "contents": [{"type": "text", "text": "Items", "size": "sm", "color": "#555555"}, {"type": "text", "text": "2", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Total", "size": "sm", "color": "#555555"}, {"type": "text", "text": "0฿", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Transport", "size": "sm", "color": "#555555"}, {"type": "text", "text": "0฿", "size": "sm", "color": "#111111", "align": "end"}]}, {"type": "box", "layout": "horizontal", "contents": [{"type": "text", "text": "Sum Total", "size": "sm", "color": "#555555"}, {"type": "text", "text": "0฿", "size": "sm", "color": "#111111", "align": "end"}]}]}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "vertical", "contents": [{"type": "text", "text": "Address", "size": "sm", "weight": "bold"}, {"type": "text", "text": "747 jubjub hanoi vietnam 78906", "size": "xs", "margin": "xs", "wrap": true}]}, {"type": "separator", "margin": "xxl"}, {"type": "box", "layout": "horizontal", "margin": "md", "contents": [{"type": "text", "text": "ORDER ID", "size": "xs", "color": "#aaaaaa", "flex": 0}, {"type": "text", "text": "#743289384279", "color": "#aaaaaa", "size": "xs", "align": "end", "wrap": false, "position": "relative"}]}, {"type": "button", "action": {"type": "uri", "label": "Transfer slip", "uri": "http://linecorp.com/"}}]}, "styles": {"footer": {"separator": true}}}'
